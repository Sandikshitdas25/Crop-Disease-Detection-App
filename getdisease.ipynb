# %%
print("hello")
# Out:
# hello

# %%
import tensorflow as tf
from tensorflow.keras import models, layers
import matplotlib.pyplot as plt

# %%
IMAGE_SIZE = 256
BATCH_SIZE = 32
CHANNELS = 3
EPOCHS = 50

# %%
dataset = tf.keras.preprocessing.image_dataset_from_directory(
    "images",
    shuffle = True,
    image_size = (IMAGE_SIZE, IMAGE_SIZE),
    batch_size = BATCH_SIZE
)
# Out:
# Found 6817 files belonging to 12 classes.

# %%
dataset.class_names
# Out:
# ['Anthracnose',
#  'Bacterialblight',
#  'Blast',
#  'Brownspot',
#  'Tungro',
#  'algal leaf',
#  'bird eye spot',
#  'brown blight',
#  'gray light',
#  'healthy',
#  'red leaf spot',
#  'white spot']

# %%
len(dataset)
# Out:
# 214

# %%
def get_dataset_partitions_tf(ds, train_split=0.8, val_split=0.1, test_split=0.1, shuffle=True, shuffle_size=10000):
    ds_size = len(ds)
    train_size = int(ds_size * train_split)
    val_size = int(ds_size * val_split)
    if shuffle:
        ds = ds.shuffle(shuffle_size, seed=12)
    train_ds = ds.take(train_size)
    val_ds = ds.skip(train_size).take(val_size)
    test_ds = ds.skip(train_size).skip(val_size)
    return train_ds, val_ds, test_ds

# %%
train_ds, val_ds, test_ds = get_dataset_partitions_tf(dataset)

# %%
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
val_ds = val_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)
test_ds = test_ds.cache().shuffle(1000).prefetch(buffer_size=tf.data.AUTOTUNE)

# %%
resize_and_rescale = tf.keras.Sequential([
    layers.Resizing(IMAGE_SIZE, IMAGE_SIZE),
    layers.Rescaling(1.0/255)
])

# %%
data_augmentation = tf.keras.Sequential([
    layers.RandomFlip("horizontal_and_vertical"),
    layers.RandomRotation(0.2)
])

# %%
n_classes = 12
model = models.Sequential([
    resize_and_rescale,
    data_augmentation,
    layers.Conv2D(32, (3,3), activation = "relu", input_shape = (BATCH_SIZE, IMAGE_SIZE, IMAGE_SIZE, CHANNELS)),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(64, kernel_size=(3,3), activation = "relu"),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(64, kernel_size=(3,3), activation = "relu"),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(64, kernel_size=(3,3), activation = "relu"),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(64, kernel_size=(3,3), activation = "relu"),
    layers.MaxPooling2D((2,2)),
    layers.Conv2D(64, kernel_size=(3,3), activation = "relu"),
    layers.MaxPooling2D((2,2)),
    layers.Flatten(),
    layers.Dense(64, activation = "relu"),
    layers.Dense(n_classes, activation="softmax")
])

model.build(input_shape = (BATCH_SIZE, IMAGE_SIZE, IMAGE_SIZE, CHANNELS))
# Out:
# C:\Users\SANDIKSHIT\anaconda3\Lib\site-packages\keras\src\layers\convolutional\base_conv.py:107: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)

# %%
model.summary()
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ sequential (Sequential)              │ (32, 256, 256, 3)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ sequential_1 (Sequential)            │ (32, 256, 256, 3)           │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d (Conv2D)                      │ (32, 254, 254, 32)          │             896 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d (MaxPooling2D)         │ (32, 127, 127, 32)          │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_1 (Conv2D)                    │ (32, 125, 125, 64)          │          18,496 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_1 (MaxPooling2D)       │ (32, 62, 62, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_2 (Conv2D)                    │ (32, 60, 60, 64)            │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_2 (MaxPooling2D)       │ (32, 30, 30, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_3 (Conv2D)                    │ (32, 28, 28, 64)            │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_3 (MaxPooling2D)       │ (32, 14, 14, 64)            │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_4 (Conv2D)                    │ (32, 12, 12, 64)            │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_4 (MaxPooling2D)       │ (32, 6, 6, 64)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ conv2d_5 (Conv2D)                    │ (32, 4, 4, 64)              │          36,928 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ max_pooling2d_5 (MaxPooling2D)       │ (32, 2, 2, 64)              │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ flatten (Flatten)                    │ (32, 256)                   │               0 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense (Dense)                        │ (32, 64)                    │          16,448 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (32, 12)                    │             780 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 184,332 (720.05 KB)
#  Trainable params: 184,332 (720.05 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
model.compile(
    optimizer="adam",
    loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=False),
    metrics=["accuracy"]
)

# %%
history = model.fit(
    train_ds,
    epochs=EPOCHS,
    batch_size=BATCH_SIZE,
    verbose=1,
    validation_data=val_ds
)
# Out:
# Epoch 1/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 325s 2s/step - accuracy: 0.2999 - loss: 1.7564 - val_accuracy: 0.5610 - val_loss: 1.1235
# Epoch 2/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 354s 2s/step - accuracy: 0.6112 - loss: 0.9927 - val_accuracy: 0.6830 - val_loss: 0.8212
# Epoch 3/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 249s 1s/step - accuracy: 0.7237 - loss: 0.6780 - val_accuracy: 0.7024 - val_loss: 0.7946
# Epoch 4/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 245s 1s/step - accuracy: 0.7807 - loss: 0.5611 - val_accuracy: 0.7708 - val_loss: 0.5512
# Epoch 5/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 247s 1s/step - accuracy: 0.8187 - loss: 0.4608 - val_accuracy: 0.8155 - val_loss: 0.4465
# Epoch 6/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 244s 1s/step - accuracy: 0.8477 - loss: 0.3831 - val_accuracy: 0.8110 - val_loss: 0.4054
# Epoch 7/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 251s 1s/step - accuracy: 0.8612 - loss: 0.3591 - val_accuracy: 0.8393 - val_loss: 0.3956
# Epoch 8/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 248s 1s/step - accuracy: 0.8807 - loss: 0.3026 - val_accuracy: 0.8750 - val_loss: 0.3237
# Epoch 9/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 250s 1s/step - accuracy: 0.8833 - loss: 0.2986 - val_accuracy: 0.8557 - val_loss: 0.3500
# Epoch 10/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 249s 1s/step - accuracy: 0.8953 - loss: 0.2668 - val_accuracy: 0.8051 - val_loss: 0.5174
# Epoch 11/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 249s 1s/step - accuracy: 0.8833 - loss: 0.2953 - val_accuracy: 0.9271 - val_loss: 0.1888
# Epoch 12/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 266s 1s/step - accuracy: 0.9201 - loss: 0.2053 - val_accuracy: 0.8943 - val_loss: 0.2524
# Epoch 13/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 254s 1s/step - accuracy: 0.8584 - loss: 0.3935 - val_accuracy: 0.9256 - val_loss: 0.1950
# Epoch 14/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 252s 1s/step - accuracy: 0.9327 - loss: 0.1735 - val_accuracy: 0.8542 - val_loss: 0.3748
# Epoch 15/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 189s 1s/step - accuracy: 0.9231 - loss: 0.2030 - val_accuracy: 0.9390 - val_loss: 0.1485
# Epoch 16/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 157s 918ms/step - accuracy: 0.9366 - loss: 0.1606 - val_accuracy: 0.9390 - val_loss: 0.1866
# Epoch 17/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 167s 978ms/step - accuracy: 0.9326 - loss: 0.1798 - val_accuracy: 0.8080 - val_loss: 0.6863
# Epoch 18/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 202s 976ms/step - accuracy: 0.8911 - loss: 0.2960 - val_accuracy: 0.9449 - val_loss: 0.1251
# Epoch 19/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 171s 1s/step - accuracy: 0.9487 - loss: 0.1266 - val_accuracy: 0.9092 - val_loss: 0.2137
# Epoch 20/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 204s 1s/step - accuracy: 0.9381 - loss: 0.1579 - val_accuracy: 0.9524 - val_loss: 0.1246
# Epoch 21/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 173s 1s/step - accuracy: 0.9483 - loss: 0.1361 - val_accuracy: 0.9479 - val_loss: 0.1231
# Epoch 22/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 174s 1s/step - accuracy: 0.9167 - loss: 0.2151 - val_accuracy: 0.9420 - val_loss: 0.1477
# Epoch 23/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 173s 1s/step - accuracy: 0.9523 - loss: 0.1138 - val_accuracy: 0.9554 - val_loss: 0.1192
# Epoch 24/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 176s 1s/step - accuracy: 0.9453 - loss: 0.1294 - val_accuracy: 0.9479 - val_loss: 0.1247
# Epoch 25/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 174s 1s/step - accuracy: 0.9291 - loss: 0.1802 - val_accuracy: 0.9583 - val_loss: 0.1132
# Epoch 26/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 182s 1s/step - accuracy: 0.9549 - loss: 0.1100 - val_accuracy: 0.9330 - val_loss: 0.1634
# Epoch 27/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 174s 1s/step - accuracy: 0.9487 - loss: 0.1276 - val_accuracy: 0.9643 - val_loss: 0.0859
# Epoch 28/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 177s 1s/step - accuracy: 0.9488 - loss: 0.1231 - val_accuracy: 0.9583 - val_loss: 0.0911
# Epoch 29/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 175s 1s/step - accuracy: 0.9459 - loss: 0.1327 - val_accuracy: 0.9018 - val_loss: 0.1984
# Epoch 30/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 198s 1s/step - accuracy: 0.9343 - loss: 0.1670 - val_accuracy: 0.9509 - val_loss: 0.1116
# Epoch 31/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 179s 1s/step - accuracy: 0.9618 - loss: 0.0928 - val_accuracy: 0.9315 - val_loss: 0.1661
# Epoch 32/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 176s 1s/step - accuracy: 0.9584 - loss: 0.1062 - val_accuracy: 0.9554 - val_loss: 0.1126
# Epoch 33/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 175s 1s/step - accuracy: 0.9634 - loss: 0.0976 - val_accuracy: 0.9598 - val_loss: 0.0865
# Epoch 34/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 173s 1s/step - accuracy: 0.9590 - loss: 0.0871 - val_accuracy: 0.9717 - val_loss: 0.0705
# Epoch 35/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 173s 1s/step - accuracy: 0.9672 - loss: 0.0804 - val_accuracy: 0.9568 - val_loss: 0.1115
# Epoch 36/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 176s 1s/step - accuracy: 0.9230 - loss: 0.2259 - val_accuracy: 0.9568 - val_loss: 0.1232
# Epoch 37/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 194s 1s/step - accuracy: 0.9561 - loss: 0.1112 - val_accuracy: 0.9479 - val_loss: 0.1011
# Epoch 38/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 260s 2s/step - accuracy: 0.9605 - loss: 0.0941 - val_accuracy: 0.9420 - val_loss: 0.1463
# Epoch 39/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 233s 1s/step - accuracy: 0.9533 - loss: 0.1116 - val_accuracy: 0.9271 - val_loss: 0.1751
# Epoch 40/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 240s 1s/step - accuracy: 0.9468 - loss: 0.1238 - val_accuracy: 0.9688 - val_loss: 0.0709
# Epoch 41/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 238s 1s/step - accuracy: 0.9626 - loss: 0.0880 - val_accuracy: 0.9598 - val_loss: 0.0790
# Epoch 42/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 234s 1s/step - accuracy: 0.9603 - loss: 0.1053 - val_accuracy: 0.9568 - val_loss: 0.1002
# Epoch 43/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 235s 1s/step - accuracy: 0.9700 - loss: 0.0776 - val_accuracy: 0.9732 - val_loss: 0.0624
# Epoch 44/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 236s 1s/step - accuracy: 0.9651 - loss: 0.0808 - val_accuracy: 0.9792 - val_loss: 0.0666
# Epoch 45/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 234s 1s/step - accuracy: 0.9514 - loss: 0.1280 - val_accuracy: 0.9643 - val_loss: 0.1065
# Epoch 46/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 233s 1s/step - accuracy: 0.9293 - loss: 0.2073 - val_accuracy: 0.9732 - val_loss: 0.0742
# Epoch 47/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 234s 1s/step - accuracy: 0.9671 - loss: 0.0759 - val_accuracy: 0.9568 - val_loss: 0.0925
# Epoch 48/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 236s 1s/step - accuracy: 0.9707 - loss: 0.0704 - val_accuracy: 0.9673 - val_loss: 0.0767
# Epoch 49/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 235s 1s/step - accuracy: 0.9603 - loss: 0.0967 - val_accuracy: 0.9464 - val_loss: 0.1506
# Epoch 50/50
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 232s 1s/step - accuracy: 0.9570 - loss: 0.1063 - val_accuracy: 0.9792 - val_loss: 0.0501

# %%
import numpy as np
for images_batch, labels_batch in test_ds.take(1):
    first_image = images_batch[0].numpy().astype("uint8")
    first_label = labels_batch[0].numpy()

    print("first image to predict: ")
    plt.imshow(first_image)
    print("actual label: ", dataset.class_names[first_label])

    batch_prediction = model.predict(images_batch)
    # print(batch_prediction[0])
    print("Predicted label: ", dataset.class_names[np.argmax(batch_prediction[0])])
# Out:
# first image to predict:
# actual label:  Blast
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 447ms/step
# Predicted label:  Blast

# %%
model.evaluate(train_ds)
# Out:
# 171/171 ━━━━━━━━━━━━━━━━━━━━ 90s 523ms/step - accuracy: 0.9746 - loss: 0.0594
# [0.05875672027468681, 0.9757397770881653]

# %%
model.save("./models/1/getdiseasename.h5")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 model.save("./models/1/")
#
# File ~\anaconda3\Lib\site-packages\keras\src\utils\traceback_utils.py:122, in filter_traceback.<locals>.error_handler(*args, **kwargs)
#     119     filtered_tb = _process_traceback_frames(e.__traceback__)
#     120     # To get the full stack trace, call:
#     121     # `keras.config.disable_traceback_filtering()`
# --> 122     raise e.with_traceback(filtered_tb) from None
#     123 finally:
#     124     del filtered_tb
#
# File ~\anaconda3\Lib\site-packages\keras\src\saving\saving_api.py:114, in save_model(model, filepath, overwrite, zipped, **kwargs)
#     110 if str(filepath).endswith((".h5", ".hdf5")):
#     111     return legacy_h5_format.save_model_to_hdf5(
#     112         model, filepath, overwrite, include_optimizer
#     113     )
# --> 114 raise ValueError(
#     115     "Invalid filepath extension for saving. "
#     116     "Please add either a `.keras` extension for the native Keras "
#     117     f"format (recommended) or a `.h5` extension. "
#     118     "Use `model.export(filepath)` if you want to export a SavedModel "
#     119     "for use with TFLite/TFServing/etc. "
#     120     f"Received: filepath={filepath}."
#     121 )
#
# ValueError: Invalid filepath extension for saving. Please add either a `.keras` extension for the native Keras format (recommended) or a `.h5` extension. Use `model.export(filepath)` if you want to export a SavedModel for use with TFLite/TFServing/etc. Received: filepath=./models/1/.
